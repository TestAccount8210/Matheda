# %% [markdown]
# # Standard Normal Distribution <hr style="border:2.5px solid #ad0000ff"></hr>

# %% [markdown]
# <b>Ivan Paul J. Untaran</b>
# <br>Computer Engineer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Z-score

# %%
df = pd.DataFrame([1,2,2,3,3,3,4,4,5],
                    columns = ['datasets'])
df
# Out:
#    datasets
# 0         1
# 1         2
# 2         2
# 3         3
# 4         3
# 5         3
# 6         4
# 7         4
# 8         5

# %%
df.describe()
# Out:
#        datasets
# count  9.000000
# mean   3.000000
# std    1.224745
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
#z-score
df['Z-score'] = stats.zscore(df['datasets'], ddof=1)
df
# Out:
#    datasets   Z-score
# 0         1 -1.632993
# 1         2 -0.816497
# 2         2 -0.816497
# 3         3  0.000000
# 4         3  0.000000
# 5         3  0.000000
# 6         4  0.816497
# 7         4  0.816497
# 8         5  1.632993

# %%
df = pd.read_csv(r"dataset\current-test.csv",
                 delimiter = ',',
                 index_col = 'Sample')
df
# Out:
#         Current
# Sample
# 1          12.0
# 2          15.0
# 3           8.3
# 4           9.7
# 5          12.0
# 6          13.9
# 7          14.1
# 8           9.2
# 9          12.4
# 10         13.7
# 11         10.6
# 12         21.5
# 13         12.0
# 14          9.3
# 15         11.2
# 16          3.3
# 17         12.4
# 18         12.3
# 19         13.8
# 20         10.5
# 21         10.4
# 22         15.0
# 23         12.7
# 24         14.4
# 25         11.0
# 26          9.1
# 27         10.2
# 28         12.4
# 29          7.0
# 30         14.8

# %%
df['Current'][2]
# Out:
# np.float64(15.0)

# %%
df['Current'][3:5]
# Out:
# Sample
# 4     9.7
# 5    12.0
# Name: Current, dtype: float64

# %%
sample_1 = (df['Current'][3:5].mean())
sample_1
# Out:
# np.float64(10.85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 30
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Current  30 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5 KB

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Current'], bins = 5,
        alpha = 0.8,
        color = '#126782',
        edgecolor = '#1C1F24')
plt.show()

# %%
plt.hist(df['Current'], bins = 5,
        alpha = 0.8,
        color = '#126782',
        edgecolor = '#1C1F24')

plt.title('Histogram of Current Values',
          font = 'Times New Roman',
          fontsize = 12)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Normal Distribution

# %%
# Normal Distribution Curve
mean = df ['Current'].mean()
std = df['Current'].std(ddof=1)

#x-axis
x_min = df['Current'].min()
x_max = df['Current'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x,mean,std)

plt.plot(x,p,
         color='#126782',
         linewidth = 2)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Current'], bins = 5,
        density = True,
        alpha = 0.8,
        color = '#126782',
        edgecolor = '#1C1F24')

plt.title('Histogram of Current Values',
          font = 'Times New Roman',
          fontsize = 12)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')

mean = df ['Current'].mean()
std = df['Current'].std(ddof=1)

#x-axis
x_min = df['Current'].min()
x_max = df['Current'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x,mean,std)

plt.plot(x,p,
         color="#F91018",
         linewidth = 2)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency')

plt.show()

# %%
#x-axis
df['Z_score'] = stats.zscore(df['Current'], ddof=1)
x_min = df['Z_score'].min()
x_max = df['Z_score'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x,df['Z_score'].mean(),
                   df['Z_score'].std(ddof=1))

plt.plot(x,p,
         color="#F91018",
         linewidth = 2)
plt.xlabel('Z-score')
plt.ylabel('Probability Density')

plt.show()

# %% [markdown]
# # List and Tuples <hr style="border:2.5px solid #ad0000ff"></hr>

# %% [markdown]
# <b>Ivan Paul J. Untaran</b>
# <br>Computer Engineer

# %% [markdown]
# # Creating a List

# %%
numbers = [1,2,3,4,5]
M
Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 numbers = [1,2,3,4,5]
# ----> 2 M
#       3 Y
#
# NameError: name 'M' is not defined

# %%
numbers

# %%
numbers[0]

# %%
type(numbers)

# %%
fruits = ["apple", "banana", "grape"]
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'apple' in fruits

# %%
mixed_list = [10, 'hello', 2.5, true]
mixed_list

# %% [markdown]
# # Removing Elements

# %%
'banana' in fruits

# %%
fruits.remove('banana')

# %%
fruits.pop(0)

# %% [markdown]
# #Sort() and Sorted()

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Slicing

# %%
chars = ['a','b','c','x','y']
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
len(chars)
# Out:
# 5

# %%
sub = chars[1:4]

# %%
sub
# Out:
# ['b', 'c', 'x']

# %%
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
chars[0:5:2]
# Out:
# ['a', 'c', 'y']

# %% [markdown]
# # Tuple

# %%
my_tuple=(1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[2]
# Out:
# 3

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[0]=1 # error ex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 my_tuple[0]=1 # error ex
#
# TypeError: 'tuple' object does not support item assignment

# %%
mixed_tuple = (10,'hello',2.5,True)
mixed_tuple
# Out:
# (10, 'hello', 2.5, True)

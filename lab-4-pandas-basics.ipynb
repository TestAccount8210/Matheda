# %% [markdown]
# # Pandas <hr style="border:2.5px solid #ad0000ff"></hr>

# %% [markdown]
# <b>Ivan Paul J. Untaran</b>
# <br>Computer Engineer

# %%
# Imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Frame

# %%
# Creating dictionary
data = {
    "Name": ["Henry", "Owen", "Ada"],
    "Age": [22, 35, 58],
    "Sex": ["M", "M", "F"]
}

# %%
# Creating dataframe from dictionary
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ada   58   F

# %% [markdown]
# # Series

# %%
# Selecting "Name" column
df["Name"]
# Out:
# 0    Henry
# 1     Owen
# 2      Ada
# Name: Name, dtype: object

# %%
# Selecting "Age" column
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# Selecting "Sex" column
df["Sex"]
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
# Jaguar vs Panther
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3.9, 8],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
])

resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3.9,  8. ],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
# Creating DataFrame from numpy array
df = pd.DataFrame(resistance.T, columns=['Jaguar', 'Panther'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Creating DataFrame from numpy array
# ----> 2 df = pd.DataFrame(resistance, columns=['Jaguar', 'Panther'])
#       3 df
#
# File c:\Users\IvanPaul\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     820         mgr = dict_to_mgr(
#     821             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     822             # attribute "name"
#    (...)    828             copy=_copy,
#     829         )
#     830     else:
# --> 831         mgr = ndarray_to_mgr(
#     832             data,
#     833             index,
#     834             columns,
#     835             dtype=dtype,
#     836             copy=copy,
#     837             typ=manager,
#     838         )
#     840 # For data is list-like, or Iterable (will consume into list)
#     841 elif is_list_like(data):
#
# File c:\Users\IvanPaul\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File c:\Users\IvanPaul\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (2, 11), indices imply (2, 2)

# %%
# Summary of dataframe
df.info()

# %%
type(df)

# %%
# Summary of statistics
df.describe()
